# %%
# Importando a biblioteca pandas
import pandas as pd

# %%
# Leituras dos arquivos
df1 = pd.read_excel("Aracaju.xlsx")
df2 = pd.read_excel("Fortaleza.xlsx")
df3 = pd.read_excel("Natal.xlsx")
df4 = pd.read_excel("Recife.xlsx")
df5 = pd.read_excel("Salvador.xlsx")

# %%
# Exibi as primeiras linhas de Aracaju
df1.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
# Juntando todos os arquivos
df = pd.concat([df1,df2,df3,df4,df5])

# %%
# Exibindo as 5 primeiras linhas
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
# Exibindo as 5 ultimas linhas
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde
# 139      Natal 2019-01-02  169.01    1036     1
# 35       Natal 2018-01-18  552.00     852     2
# 8        Natal 2019-03-27  667.00     852     4
# 13   Fortaleza 2019-02-12  118.58    1003     4
# 50      Recife 2019-01-01    7.24     983     4

# %%
# Verificando o tipo de dado de cada coluna
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
# Alterando o tipo de dado da coluna LojaID
df["LojaID"] = df["LojaID"].astype("object")

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde               int64
# dtype: object

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00   1520     1
# 1  Aracaju 2018-01-01   14.21   1522     6
# 2  Aracaju 2018-01-01   71.55   1520     1
# 3  Aracaju 2018-01-01    3.01   1521     7
# 4  Aracaju 2018-01-01   24.51   1522     8

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
# Substituido os valores nulos pela media
df["Vendas"].fillna(df["Vendas"].mean(), inplace=True)

# %%
df["Vendas"].mean()
# Out:
# 122.61180089485438

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df.sample(15)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde
# 190   Salvador 2019-01-02   78.78   1035     3
# 93       Natal 2019-01-02   15.58   1037     1
# 25      Recife 2019-01-01  161.60    982     5
# 209   Salvador 2019-01-02   69.98   1034     2
# 114      Natal 2019-01-02   25.52   1034     1
# 239   Salvador 2019-01-03  161.41   1037     3
# 75      Recife 2019-01-01  170.29    981     8
# 138   Salvador 2019-03-02  212.03   1037     3
# 188   Salvador 2019-01-02  178.11   1035     3
# 24   Fortaleza 2019-01-01   35.38   1005     4
# 122      Natal 2019-01-02   13.27   1037     1
# 94    Salvador 2019-01-01   33.24   1037     1
# 31     Aracaju 2018-01-01  171.16   1520     9
# 170   Salvador 2019-01-02    9.26   1035     3
# 49    Salvador 2019-01-01   37.88   1034     2

# %%
# Substituindo os valores nulos por zero
df["Vendas"].fillna(0, inplace=True)

# %%
## Apagando as linhas com valores nulos
df.dropna(inplace=True)

# %%
# Apagando as linhas com valores nulos com base apenas em 1 coluna
df.dropna(subset=["Vendas"], inplace=True)

# %%
# Removendo linhas que estejam com valores faltantes em todas as colunas
df.dropna(how="all", inplace=True)

# %% [markdown]
# **Criando novas colunas**

# %%
# Criando a coluna de receita
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08

# %%
df["Receita/Vendas"] = df["Receita"] / df["Vendas"]

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00             1.0
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26             6.0
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55             1.0
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07             7.0
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08             8.0

# %%
#Retornando a maior receita
df["Receita"].max()
# Out:
# 3544.0

# %%
# Retornando a menor receita
df["Receita"].min()
# Out:
# 3.34

# %%
# Retorna o top 3 linhas com maiores receitas
df.nlargest(3, "Receita")
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 7   Natal 2019-03-18   886.0    853     4   3544.0             4.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0             4.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0             4.0

# %%
# Retorna o top 3 linhas com menores receitas
df.nsmallest(3, "Receita")
# Out:
#       Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 118  Aracaju 2018-01-01    3.34   1522     1     3.34             1.0
# 65    Recife 2019-01-01    4.01    981     1     4.01             1.0
# 92     Natal 2019-01-02    4.57   1035     1     4.57             1.0

# %%
# Agrupamento por cidade
df.groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receita, dtype: float64

# %%
# Ordenando o conjunto de dados
df.sort_values("Receita", ascending=False).head(10)
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 7   Natal 2019-03-18   886.0    853     4   3544.0             4.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0             4.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0             4.0
# 30  Natal 2018-10-02   856.0    853     4   3424.0             4.0
# 41  Natal 2018-05-20   835.0    852     4   3340.0             4.0
# 38  Natal 2018-02-25   828.0    852     4   3312.0             4.0
# 10  Natal 2018-10-27   828.0    852     4   3312.0             4.0
# 69  Natal 2019-03-24   817.0    852     4   3268.0             4.0
# 62  Natal 2018-02-10   793.0    854     4   3172.0             4.0
# 52  Natal 2018-04-27   778.0    854     4   3112.0             4.0

# %% [markdown]
# # **Trabalhando com datas**

# %%
# Transformando a coluna de data em tipo inteiro
df["Data"] = df["Data"].astype("int64")

# %%
# Verificando o tipo de dado de cada coluna
df.dtypes
# Out:
# Cidade             object
# Data                int64
# Vendas            float64
# LojaID             object
# Qtde                int64
# Receita           float64
# Receita/Vendas    float64
# dtype: object

# %%
# Transformando coluna de data em data
df["Data"] = pd.to_datetime(df["Data"])

# %%
df.dtypes
# Out:
# Cidade                    object
# Data              datetime64[ns]
# Vendas                   float64
# LojaID                    object
# Qtde                       int64
# Receita                  float64
# Receita/Vendas           float64
# dtype: object

# %%
# Agrupamento por ano
df.groupby(df["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
# Criando uma nova coluna com o ano
df["Ano_Venda"] = df["Data"].dt.year

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  ...  Receita  Receita/Vendas  Ano_Venda
# 73      Recife 2019-01-01   39.71  ...   198.55             5.0       2019
# 120      Natal 2019-01-02  140.17  ...   280.34             2.0       2019
# 78     Aracaju 2018-01-01  154.85  ...  1393.65             9.0       2018
# 88       Natal 2019-01-02   31.20  ...    31.20             1.0       2019
# 6    Fortaleza 2019-01-01   38.40  ...   153.60             4.0       2019
#
# [5 rows x 8 columns]

# %%
# Extraindo o mês e o dia
df["mes_venda"], df["dia_venda"] = (df["Data"].dt.month, df["Data"].dt.day)

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas  ... Ano_Venda  mes_venda  dia_venda
# 39      Natal 2019-01-10  504.00  ...      2019          1         10
# 91    Aracaju 2018-01-01  200.85  ...      2018          1          1
# 42     Recife 2019-01-01  161.45  ...      2019          1          1
# 202  Salvador 2019-01-02   22.45  ...      2019          1          2
# 114    Recife 2019-03-02   16.82  ...      2019          3          2
#
# [5 rows x 10 columns]

# %%
# Retornando a data mais antiga
df["Data"].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
# Calculando a diferença de dias
df["diferenca_dias"] = df["Data"] - df["Data"].min()

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas  ... mes_venda  dia_venda  diferenca_dias
# 17      Natal 2018-02-18  276.00  ...         2         18         48 days
# 150     Natal 2019-01-02   11.13  ...         1          2        366 days
# 36     Recife 2019-01-01  146.62  ...         1          1        365 days
# 205  Salvador 2019-01-02  196.09  ...         1          2        366 days
# 13   Salvador 2019-02-12   39.29  ...         2         12        407 days
#
# [5 rows x 11 columns]

# %%
# Criando a coluna de trimestre
df["trimestre_venda"] = df["Data"].dt.quarter

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas  ... dia_venda  diferenca_dias  trimestre_venda
# 73    Aracaju 2018-01-01  159.78  ...         1          0 days                1
# 93      Natal 2019-01-02   15.58  ...         2        366 days                1
# 21   Salvador 2019-01-01   39.72  ...         1        365 days                1
# 112  Salvador 2019-03-02   43.00  ...         2        425 days                1
# 223  Salvador 2019-01-02   40.51  ...         2        366 days                1
#
# [5 rows x 12 columns]

# %%
# Filtrando as vendas de 2019 do mês de março
vendas_marco_19 = df.loc[(df["Data"].dt.year == 2019) & (df["Data"].dt.month == 3)]

# %%
vendas_marco_19
# Out:
#         Cidade       Data  Vendas  ... dia_venda  diferenca_dias  trimestre_venda
# 108  Fortaleza 2019-03-02  152.89  ...         2        425 days                1
# 109  Fortaleza 2019-03-02   18.90  ...         2        425 days                1
# 110  Fortaleza 2019-03-02   51.98  ...         2        425 days                1
# 111  Fortaleza 2019-03-02    8.00  ...         2        425 days                1
# 112  Fortaleza 2019-03-02  133.59  ...         2        425 days                1
# ..         ...        ...     ...  ...       ...             ...              ...
# 137   Salvador 2019-03-02   51.66  ...         2        425 days                1
# 138   Salvador 2019-03-02  212.03  ...         2        425 days                1
# 139   Salvador 2019-03-02  169.01  ...         2        425 days                1
# 140   Salvador 2019-03-02   20.79  ...         2        425 days                1
# ...

# %%
vendas_marco_19.sample(20)
# Out:
#         Cidade       Data  Vendas  ... dia_venda  diferenca_dias  trimestre_venda
# 82       Natal 2019-03-07  868.00  ...         7        430 days                1
# 74       Natal 2019-03-10  303.00  ...        10        433 days                1
# 141   Salvador 2019-03-02    9.08  ...         2        425 days                1
# 71       Natal 2019-03-20  840.00  ...        20        443 days                1
# 124   Salvador 2019-03-02   44.82  ...         2        425 days                1
# 113  Fortaleza 2019-03-02   38.63  ...         2        425 days                1
# 121  Fortaleza 2019-03-02   41.55  ...         2        425 days                1
# 140     Recife 2019-03-02  166.89  ...         2        425 days                1
# 138     Recife 2019-03-02  150.38  ...         2        425 days                1
# 117     Recife 2019-03-02   15.42  ...         2        425 days                1
# ...

# %% [markdown]
# # **Visualização de dados**

# %%
# Mostra as lojas com os seus respectivos numero de vendas
df["LojaID"].value_counts(ascending=False)
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1002     30
# 1005     30
# 852      29
# 1523     29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
# Gráfico de barras
df["LojaID"].value_counts(ascending=False).plot.bar()

# %%
# Grafico de barras horizontais.  Se inserir o ";" ao final da linha de codigo o mesmo nao exibe os codigos. somente o grafico.
df["LojaID"].value_counts(ascending=True).plot.barh()

# %%
# Grafico de Pizza
df.groupby(df["Data"].dt.year)["Receita"].sum().plot.pie()

# %%
# Total vendas por cidade
df["Cidade"].value_counts()
# Out:
# Salvador     240
# Natal        240
# Fortaleza    142
# Recife       142
# Aracaju      130
# Name: Cidade, dtype: int64

# %%
# Adicionando um titulo e alterando o nome dos eixos
import matplotlib.pyplot as plt
df["Cidade"].value_counts().plot.bar(title="Total vendas por Cidade")
plt.xlabel("Cidade")
plt.ylabel("Total Vendas");

# %%
# Alterando a cor
df["Cidade"].value_counts().plot.bar(title="Total vendas por Cidade", color="red")

# %%
# Alterando o estilo
plt.style.use("ggplot")

# %%
df.groupby(["mes_venda"])["Qtde"].sum().plot(title = "Total produtos vendidos no mês")
plt.xlabel("Mês")
plt.ylabel("Total Produtos Vendidos")
plt.legend()

# %%
df.groupby(df["mes_venda"])["Qtde"].sum()
# Out:
# mes_venda
# 1     2208
# 2      144
# 3      467
# 4       23
# 5       17
# 6       13
# 7       13
# 8        2
# 9       10
# 10      14
# 11       2
# 12       3
# Name: Qtde, dtype: int64

# %%
# Selecionando apenas as vendas de 2010
df_2019 = df[df["Ano_Venda"] == 2019]

# %%
df_2019.groupby(df_2019["mes_venda"])["Qtde"].sum()
# Out:
# mes_venda
# 1    1541
# 2     128
# 3     460
# 4      12
# Name: Qtde, dtype: int64

# %%
# Total produtos vendidos por mês
df_2019.groupby(df_2019["mes_venda"])["Qtde"].sum().plot(marker = "v")
plt.xlabel("mês")
plt.ylabel("Total Produtos vendidos");
plt.legend();

# %%
# Histograma
plt.hist(df["Qtde"], color="orangered");

# %%
plt.scatter(x=df_2019["dia_venda"], y = df_2019["Receita"]);

# %%
# Salvando em png
df_2019.groupby(df_2019["mes_venda"])["Qtde"].sum().plot(marker = "v")
plt.title("Quantidade de produtos vendidos x mês")
plt.xlabel("Mês")
plt.ylabel("Total Produtos Vendidos");
plt.legend()
plt.savefig("grafico QTDE x MÊS.png")
